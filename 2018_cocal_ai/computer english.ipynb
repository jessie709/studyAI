# %% [markdown]
# # 20181023
# environment
# escalation
# dispersant
# bps
# insulation
# bel
# access
# regardless
# author
# week
# singificand
# dispose
# prestore
# repository
# creator
# readily
# killwatt
# librarian
# device
# wafer
# inhibit
# redo
# aband
# accessible
# customize
# tell
# equle
# action
# denormal
# concatenation
# author

# %% [markdown]
# # 20181024
# continue
# host
# acknowledgment
# acoustic
# authenticator
# prefer
# carriage
# manifest
# abstract
# temporary
# activation
# migrate
# activity
# unsuccessful
# directory
# placement
# coexistence
# virtual
# duplication
# shmid
# debug
# smooth
# dispatch
# incoming
# sentence
# addressability
# online
# content
# evaluate
# adjacency

# %% [markdown]
# # 20181025
# trunk
# factorization
# comparand
# lux
# marker
# solution
# clerk
# mono
# memo
# state
# watt
# remain
# katakana
# multiplicity
# interrelated
# archive
# situation
# alert
# available
# triplet
# mistake
# standardize
# influence
# checker
# transcribe
# alignment
# solve
# bulid
# command
# kilobyte
# reenter

# %% [markdown]
# # 20181026
# grab
# kilogram
# preprocessor
# cpu
# real
# increasing
# terminatie
# categroy
# odometer
# rebinding
# refile
# warehouse
# copyright
# cut
# answering
# subpattern
# vocoder
# kilogram
# statement
# effect
# void
# unlink
# fuse
# maintenance
# apostrophe
# repeater
# century
# month
# photoconductor
# linestyle
# techometer

# %% [markdown]
# # 20181027
# balance
# wiring
# see
# explanation
# occasionally
# traversal
# arrangement
# exceeded
# logger
# stop
# transcation
# exceeded
# logger
# stop
# transaction
# dispatcher
# halt
# determinant
# assembled
# modular
# keyword
# spooler
# iteration
# assign
# assigned
# entrance
# simplex
# assistance
# programming
# labor
# attenuater
# report
# coax
# untilization

# %% [markdown]
# # 20181028
# decode
# unused
# profiling
# turnkey
# autostart
# captial
# adapabile
# status
# consist
# tag
# charater
# clearinghous
# diagnose
# overviwe
# seek
# zone
# reusable
# coordinate
# augment
# skew
# bellfast
# nonupdatedable
# additive
# emphasize
# critical
# return
# accumulater
# tiny
# hold
# compose

# %% [markdown]
# # 20181029
# amplitude
# automatically
# suspension
# programer
# upper
# diphthong
# header
# metafile
# mashal
# rated
# traffic
# precede
# dismount
# administrative
# repair
# compute
# incompatiable
# backlog
# commitment
# backslash
# decipher
# visiblity
# metadata
# negotiation
# depress
# alarm
# enquir
# collator
# decrease
# complment

# %% [markdown]
# # 20181030
# bar
# hm
# stipple
# baseline
# basename
# bass
# business
# basis
# courier
# composition
# bootstrap
# rectangle
# layer
# hide
# picking
# subassembly
# buzzer
# variety
# spelling
# showing
# below
# terminator
# identify
# bias
# pane
# videodisc
# asterisk
# promote
# bottom
# below
# identify
# linestay

# %% [markdown]
# #20181031
# precise(精准)
# sheme(方案)
# penalty(惩罚)
# algorithm(结算)
# specity(指定的)
# parameter（虚参）
# argument(实参)
# dimensional(空间的)
# Versatile:(多功能的)
# over-fitting(过度拟合)
# crucial

# %% [markdown]
# # 20181106
# specifically
# billing
# millisecond
# vcr
# picture
# storage
# decurl
# alphabetic
# segmentation
# pack
# octal
# silder
# primitive
# branch
# break
# breakpoint
# regeneration
# bridge
# contain
# bright
# maximize
# broadband
# unmarshalling
# browse
# feminine
# amplifier
# indenfinitely
# buffering
# button
# relocation

# %% [markdown]
# # 20181107
# pixel
# bumper
# rail
# congestion
# communication
# turnover
# busy
# area
# validation
# mailer
# eraser
# suggestion
# specification
# filename
# runtime
# numeric
# analysis
# experience
# inline
# implosion
# tabulator
# erase
# event
# fix
# cost
# recursion
# permit
# make
# printbable
# when

# %% [markdown]
# # 20181108
# internetwork
# blip
# percondition
# declared
# capable
# deconcentration
# deliver
# framing
# upon
# sensitivity
# priority
# deviation
# document
# through
# inaccessible
# bitmap
# power
# tube
# relocatable
# solely
# factor
# audit
# protection
# coexit
# equation
# will
# failura
# crew
# connectivity
# weatherproof

# %% [markdown]
# # 20181112
# printout
# graphics
# gateway
# disable
# grave
# cedilla
# accelerator
# base
# autonumber
# paranthesis
# preanalysis
# input
# twentieth
# exit
# thousand
# console
# algebraic
# finally
# assumed
# chained
# overdot
# times
# simulator
# band
# infinite
# wait
# frequently
# acknowledge
# conversion
# remote

# %% [markdown]
# # 20181114
# descend
# usage
# descend
# marked
# timesllicing
# increment
# selection
# designated
# micordocument
# keypunch
# starting
# loop
# inspection
# jack
# speciallize
# intelligence
# again
# coefficient
# issue
# adapter
# visiable
# searching
# workday
# icelandic
# successive
# unescaped
# cillision
# central
# imbedded
# terminology

# %% [markdown]
# # 20181116
# click
# tasking
# formatted
# temporarily
# contextual
# swapping
# generate
# callback
# poll
# inform
# response
# catch
# compact
# postpone
# physically
# language
# array
# scheduled
# variance
# medialess
# session
# interest
# localization
# stopping
# reproducer
# DASD
# attached
# information
# repeat

# %% [markdown]
# # 20181121-18
#
# rerun
# menu
# child
# anode
# components
# biquinary
# dictionary
# zip
# battery
# remove
# marshalling
# factorial
# peer
# enhance
# logice
# computing
# frame
# multiprocessor
# though
# improvement
# text
# trigger
# concurrent
# collection
# analog
# expletive
# find
# compress
# exponent
# subchannel

# %% [markdown]
# # 20181122-19
# lockup
# overwrite
# filter
# demultiplexer
# confirmation
# star
# calendar
# rebuild
# dynamic
# linewidth
# launch
# requirment
# navigational
# associated
# superclient
# regard
# commodity
# desired
# deter
# derivation
# skulk
# divide
# coder
# quinary
# jam
# depend
# move
# number
# splitting
# mainipulator

# %% [markdown]
# # 20181123-20
# translater
# renovate
# enclave
# correct
# inhibited
# indentically
# hypertext
# convention
# cutoff
# grid
# reduce
# neutral
# override
# nest
# navigation
# atomicity
# expand
# drop
# unblock
# vga
# bpi
# valuable
# bionics
# synchronizaton
# operation
# guide
# convenience
# convenient
# embedded
# writer

# %% [markdown]
# # 20181126-bayes theorem
# skeptiocal(怀疑)
# breathalyzer test(呼吸测试)
# translater
# renovate
# enclave
# correct
# inhibited
# identically
# hypertext
# convert
# grid
# reduce
# neutral
# override
# nest
# navigation
# atomicity
# expand
# drop
# unblock
# vaga
# bpi
# synchronization
# operation
# guide
# convenient
# embedded

# %% [markdown]
# # 20181203-21
#
# converg
# title
# operand
# automation
# macrolibrary
# convert
# pad
# warranty
# movement
# respect
# graphically
# performance
# typefont
# completely
# pipe
# understanding
# transform
# fail
# mismatch
# noninventory
# redraw
# opinion
# equalization
# correspond
# inactive
# fail
# diskette
# dirid
# considered
# detect
# leaves

# %% [markdown]
# # 20190114
#
# binary
# distinguish
# strategy
# digit
# versus
# manipulating
# script

# %% [markdown]
# # 20190325
# configration bin
# start root
# sbin
# bin
# cd cd cd cd ifconfig
# ssh  zookeeper
# hadoop
# hadoop
# hadoop
# configuration property
# propertries value
# name
# shuffle
# shuffle
# ifconfig dfs
# hdfs
# hdfs
# hdfs
# hdfs
# yarn
# yarn yarn local
# local
# local map reduce
# web job defual
#
# browse the web interface for the resourceManager; by default it is available at:
#     resourceManager - http://localhost:8088/
#             run a MapReduce job.
#             When you're done,stop the daemons with:
#             sbin/stop-yarn.sh
#             this  document describes how to install and configure hadoop culsters ranging from a few nodes to extremly large clusters with thousands of nodes, to play with hadoop you may first want to install it on a single machine(see Single Node setup)
#             this document does not cover advanced topics such as Secury or High  Availabilty.
# prerequisite
# install sJava see the hadoop wiki for known good versions
# download a stable version of hadoop from apache mirrors
#
# installation
# installing a hadoop cluser typically involves the software on all the machines in the cluster or installing it via a packaging system as approprate for your operatign system. it is  important to divide up the hardware into functions.
# typically one machine in the cluster is desinated as the Namenode and another machine as the resourceManager, exclusively. these are the master. other services(such as Web App Proxy server and mapreduce joh histroy server)are usualy run either on dedicated hardware or on shared infrastructure, depending up on the load.
# the rest of the machines in the cluster act as both datanode and nodamanager there are the workers。
#
# Configuring hadoop in non-secure mode
# hadoop's java configuring is driven by two type of important configuration files
# - read -only default configuration -core -default.xml,yarn-default.xml and mapred-default.xml.
# - site- specific configuration-etc/hadoop/core-site.xml ,etc/hadoop/hdfs-site.xml,etc/hadoop/yarn-site.xml and etc/hadoop/mapred-site.xml.
# andditionally, you can control the hadoop scripts found in the bin/directory of the distribution, by setting site-specific values via the etc/hadoop/hadoops-env.sh and etc/hadoop/yarn -env.sh.
# to configure the hadoop cluster you will need to config the environment in which the hadoop daemons execute as well as the configuration parameter for the hadoop daemons.
#
# hdfs daemons are namenode sonf secondarynode and datanode,yarn daemons are resourcemanager nodemanager and webapp proxy. if mapreduces is to be used then the mapreduce jobhistory server will also be running, for large installation , there are generally running on separate hosts.
